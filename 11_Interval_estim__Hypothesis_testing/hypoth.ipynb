# %% [markdown]
# # Задача 1

# %%
x1=[12,36,60,84,108,132,156,180,204]
n1=[1,2,4,6,12,16,6,2,1]
n=sum(n1)
print(n)
x=1/n*(x1[0]*n1[0]+x1[1]*n1[1]+x1[2]*n1[2]+x1[3]*n1[3]+x1[4]*n1[4]+x1[5]*n1[5]+x1[6]*n1[6]+x1[7]*n1[7]+x1[8]*n1[8])
D=((((x1[0]**2)*n1[0])+((x1[1]**2)*n1[1])+((x1[2]**2)*n1[2])+((x1[3]**2)*n1[3])+((x1[4]**2)*n1[4])+((x1[5]**2)*n1[5])+((x1[6]**2)*n1[6])+((x1[7]**2)*n1[7])+((x1[8]**2)*n1[8]))/n)-(x**2)

G=D**0.5
print(x,D,G)

z=[(24-x)/G, (48-x)/G, (72-x)/G, (96-x)/G, (120-x)/G, (144-x)/G, (168-x)/G, (192-x)/G, (216-x)/G ]
print(z)
Fz=[-0.4913, -0.4599, -0.3686, -0.1879, 0.0517, 0.2794, 0.4192, 0.4783, 0.4961]
P=[Fz[0]+0.5,Fz[1]-Fz[0], Fz[2]-Fz[1], Fz[3]-Fz[2], Fz[4]-Fz[3], Fz[5]-Fz[4], Fz[6]-Fz[5], Fz[7]-Fz[6], Fz[8]-Fz[7]]
ni=[50*P[0], 50*P[1],50*P[2],50*P[3],50*P[4],50*P[5],50*P[6],50*P[7],50*P[8]]
print(ni)
Kemp=(n1[0]-ni[0])**2/ni[0]+(n1[1]-ni[1])**2/ni[1]+(n1[2]-ni[2])**2/ni[2]+(n1[3]-ni[3])**2/ni[3]+(n1[4]-ni[4])**2/ni[4]+(n1[5]-ni[5])**2/ni[5]+(n1[6]-ni[6])**2/ni[6]+(n1[7]-ni[7])**2/ni[7]+(n1[8]-ni[8])**2/ni[8]
print(Kemp)
r=9-2-1
Kkr=16.8
# Out:
# 50
# 114.72 1452.441600000002 38.1109118232561
# [-2.3804206107879238, -1.7506797084630763, -1.1209388061382286, -0.4911979038133811, 0.1385429985114665, 0.768283900836314, 1.3980248031611617, 2.027765705486009, 2.657506607810857]
# [0.4349999999999993, 1.570000000000002, 4.5649999999999995, 9.034999999999998, 11.98, 11.385, 6.990000000000002, 2.954999999999999, 0.8899999999999991]
# 4.274263007700842

# %% [markdown]
# Kкр>ніж Кемп тож Н0 нульова гіпотеза що це нормальний розподіл приймається

# %% [markdown]
# # Задача 2

# %%
P=0.4
Mx=2
# P(X>=3)=0.4  M(X)=2

# G=(n*Dx)**0.5
# P=0.5-Ф((3-2)/G)
# 0.4=0.5-Ф((3-2)/G)
# Ф((3-2)/G)=0.1
# (3-2)/G=0.0398
G=1/0.0398
print(G)
# Out:
# 25.125628140703515
